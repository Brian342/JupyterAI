# %% [markdown]
# # Data extraction on the safaricom reviews

# %%
# importing modules
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from bs4 import BeautifulSoup
import time

import undetected_chromedriver as uc

# %%
driver = uc.Chrome()
driver.maximize_window()
driver.get(
    'https://www.glassdoor.com/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm?filter.iso3Language=eng')
wait = WebDriverWait(driver, 10)
input("please enter to close browser")
print(driver.title)

driver.quit()
# Out:
# please enter to close browser h
# Safaricom Reviews in Kenya | Glassdoor

# %%
import undetected_chromedriver as uc

options = uc.ChromeOptions()
options.headless = False  # Set to True if you want to hide browser

driver = uc.Chrome(options=options)
driver.get("https://www.glassdoor.com/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm?filter.iso3Language=eng")

# Let the page load
time.sleep(50)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())

driver.quit()
# Out:
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/">
#  <head>
#   <style>
#    .ckimg{height:auto !important; max-width:300px;}
#   </style>
#   <link href="/web-core-sam/static/core-25e6820d85a645be.min.css" rel="stylesheet" type="text/css"/>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="#0caa41" name="theme-color"/>
#   <meta content="#0caa41" name="msapplication-navbutton-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="0" http-equiv="Expires"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="nocache" name="Bingbot"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://www.facebook.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link href="https://cdnjs.cloudflare.com" rel="preconnect"/>
#   <link as="font" crossorigin="" href="https://www.glassdoor.com/assets/fonts/GlassdoorSans-Regular.woff2?v=20240110" rel="preload" type="font/woff2"/>
#   <style>
#    /* Glassdoor Sans Initial */
# @font-face {
#   font-family: 'Glassdoor Sans Initial';
#   src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Regular.woff2?v=20240110') format('woff2');
#   font-display: swap;
# }
#
# /* Glassdoor Sans */
# /* These fonts are loaded after the initial font for performance reasons */
#
# @font-face {
#   font-family: 'Glassdoor Sans';
#   src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Regular.woff2?v=20240110') format('woff2');
#   font-weight: 400;
#   font-display: swap;
# }
#
# @font-face {
#   font-family: 'Glassdoor Sans';
#   src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Semibold.woff2?v=20240110') format('woff2');
#   font-weight: 600;
#   font-display: swap;
# }
#
# @font-face {
#   font-family: 'Glassdoor Sans';
#   src: url('https://www.glassdoor.com/assets/fonts/GlassdoorSans-Extrabold.woff2?v=20240110') format('woff2');
#   font-weight: 800;
#   font-display: swap;
# }
#
# :root {
#   --gd-product-font: 'Glassdoor Sans', 'Glassdoor Sans Initial', sans-serif;
#   font-family: var(--gd-product-font);
#   /* This is depreciated but is being used in UI Kit v1 Retrofit so it needs to continue to exist for now */
#   --gd-product-theme-font: var(--gd-product-font);
#   --gd-product-theme-rebranded-font: var(--gd-product-theme-font);
# }
#   </style>
#   <link href="/app-install-sam-server/static/marketingBanner-d64da7f07e862c7b.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/user-alert-sam-server/static/lib-37dab083763246ae.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/user-alert-sam-server/static/userAlertBanner-8b473ac420f9a653.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/sam-global-nav/static/lib-89ef839260bfd78a.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/sam-global-nav/static/globalNav-2c88cdf9231db84a.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://js.clrt.ai" rel="preconnect"/>
#   <script async="" src="https://cl.qualaroo.com/ki.js/67252/fQHqoo.js" type="text/javascript">
#   </script>
#   <script async="" src="//s3.amazonaws.com/ki.js/67252/fQH.js" type="text/javascript">
#   </script>
#   <script async="" src="https://js.clrt.ai/9598.js" type="text/javascript">
#   </script>
#   <link as="image" fetchpriority="high" href="/assets/images/infosite/default-ei-banner.jpg" rel="preload"/>
#   <title>
#    Safaricom Reviews in Kenya | Glassdoor
#   </title>
#   <meta content="Safaricom Reviews in Kenya" property="og:title"/>
#   <meta content="1,403 Safaricom reviews in Kenya. A free inside look at company reviews and salaries posted anonymously by employees." name="description"/>
#   <meta content="1,403 Safaricom reviews in Kenya. A free inside look at company reviews and salaries posted anonymously by employees." property="og:description"/>
#   <meta content="Glassdoor" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <link href="https://www.glassdoor.com/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" rel="canonical"/>
#   <link href="https://www.glassdoor.at/Bewertungen/Safaricom-Kenya-Bewertungen-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="de-AT" rel="alternate"/>
#   <link href="https://de.glassdoor.ch/Bewertungen/Safaricom-Kenya-Bewertungen-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="de-CH" rel="alternate"/>
#   <link href="https://www.glassdoor.de/Bewertungen/Safaricom-Kenya-Bewertungen-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="de-DE" rel="alternate"/>
#   <link href="https://www.glassdoor.com.au/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-AU" rel="alternate"/>
#   <link href="https://www.glassdoor.ca/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-CA" rel="alternate"/>
#   <link href="https://www.glassdoor.co.uk/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-GB" rel="alternate"/>
#   <link href="https://www.glassdoor.com.hk/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-HK" rel="alternate"/>
#   <link href="https://www.glassdoor.ie/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-IE" rel="alternate"/>
#   <link href="https://www.glassdoor.co.in/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-IN" rel="alternate"/>
#   <link href="https://www.glassdoor.co.nz/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-NZ" rel="alternate"/>
#   <link href="https://www.glassdoor.sg/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en-SG" rel="alternate"/>
#   <link href="https://www.glassdoor.com/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="en" rel="alternate"/>
#   <link href="https://www.glassdoor.com.ar/Evaluaciones/Safaricom-Kenya-Evaluaciones-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="es-AR" rel="alternate"/>
#   <link href="https://www.glassdoor.es/Opiniones/Safaricom-Kenya-Opiniones-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="es-ES" rel="alternate"/>
#   <link href="https://www.glassdoor.com.mx/Evaluaciones/Safaricom-Kenya-Evaluaciones-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="es-MX" rel="alternate"/>
#   <link href="https://fr.glassdoor.be/Avis/Safaricom-Kenya-Avis-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="fr-BE" rel="alternate"/>
#   <link href="https://fr.glassdoor.ca/Avis/Safaricom-Kenya-Avis-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="fr-CA" rel="alternate"/>
#   <link href="https://fr.glassdoor.ch/Avis/Safaricom-Kenya-Avis-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="fr-CH" rel="alternate"/>
#   <link href="https://www.glassdoor.fr/Avis/Safaricom-Kenya-Avis-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="fr-FR" rel="alternate"/>
#   <link href="https://www.glassdoor.it/Recensioni/Safaricom-Kenya-Recensioni-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="it-IT" rel="alternate"/>
#   <link href="https://nl.glassdoor.be/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="nl-BE" rel="alternate"/>
#   <link href="https://www.glassdoor.nl/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="nl-NL" rel="alternate"/>
#   <link href="https://www.glassdoor.com.br/Avalia%C3%A7%C3%B5es/Safaricom-Kenya-Avaliações-EI_IE304581.0,9_IL.10,15_IN130.htm" hreflang="pt-BR" rel="alternate"/>
#   <link href="/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130_P2.htm?filter.iso3Language=eng" rel="next"/>
#   <link href="ios-app://589698942/glassdoor/www.glassdoor.com/Reviews/Safaricom-Reviews-E304581.htm" rel="alternate"/>
#   <link href="android-app://com.glassdoor.app/glassdoor/reviews/E304581" rel="alternate"/>
#   <link href="/global-footer-sam/static/legacyFooter-feec95a6477ed61d.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/user-login-sam-server/static/legacy/gd-user-login.bundle.css?v=27f7f" rel="stylesheet" type="text/css"/>
#   <link href="/user-login-sam-server/static/legacy/gd-user-login-community.bundle.css?v=692eb" rel="stylesheet" type="text/css"/>
#   <meta charset="utf-8"/>
#   <link href="/web-core-sam/static/core-25e6820d85a645be.min.css" rel="stylesheet" type="text/css"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="65" name="next-head-count"/>
#   <script data-nscript="beforeInteractive" id="breadcrumb-jsonld" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Reviews","item":"https://www.glassdoor.com/Reviews/index.htm"},{"@type":"ListItem","position":2,"name":"Safaricom","item":"https://www.glassdoor.com/Reviews/Safaricom-Reviews-E304581.htm"},{"@type":"ListItem","position":3,"name":"Kenya","item":"https://www.glassdoor.com/Reviews/Safaricom-Kenya-Reviews-EI_IE304581.0,9_IL.10,15_IN130.htm"}]}
#   </script>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/e7ce2b22bde29f65.css" rel="preload"/>
#   <link data-n-g="" href="/ei-reviews-next/assets/_next/static/css/e7ce2b22bde29f65.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/6efc19cc6626dfdb.css" rel="preload"/>
#   <link data-n-p="" href="/ei-reviews-next/assets/_next/static/css/6efc19cc6626dfdb.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/90b88ab8f28a730b.css" rel="preload"/>
#   <link data-n-p="" href="/ei-reviews-next/assets/_next/static/css/90b88ab8f28a730b.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/e84e2ce70102a07b.css" rel="preload"/>
#   <link data-n-p="" href="/ei-reviews-next/assets/_next/static/css/e84e2ce70102a07b.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/1bc575ecc1530ba6.css" rel="preload"/>
#   <link data-n-p="" href="/ei-reviews-next/assets/_next/static/css/1bc575ecc1530ba6.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/bef9bf66181a866e.css" rel="preload"/>
#   <link data-n-p="" href="/ei-reviews-next/assets/_next/static/css/bef9bf66181a866e.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/7098fe4fe5b9a065.css" rel="preload"/>
#   <link href="/ei-reviews-next/assets/_next/static/css/7098fe4fe5b9a065.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/8d0085342066293b.css" rel="preload"/>
#   <link href="/ei-reviews-next/assets/_next/static/css/8d0085342066293b.css" rel="stylesheet"/>
#   <link as="style" href="/ei-reviews-next/assets/_next/static/css/5c540b2459618ff8.css" rel="preload"/>
#   <link href="/ei-reviews-next/assets/_next/static/css/5c540b2459618ff8.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/ei-reviews-next/assets/_next/static/chunks/polyfills-42372ed130431b0a.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="/web-core-sam/static/core-230d54c5e40c76b7.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="/web-core-sam/static/sw-register-798e02d10b3e873d.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="/assets/bundles/brand-views/gd-brand-views.bundle.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react/18.3.1/umd/react.production.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-dom/18.3.1/umd/react-dom.production.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="https://cdnjs.cloudflare.com/ajax/libs/prop-types/15.7.2/prop-types.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="https://cdnjs.cloudflare.com/ajax/libs/classnames/2.2.5/index.min.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/5236.1dc3bb3ce5a0fd19.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/webpack-df66fc4a59e591cc.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/framework-7d6705b570480543.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/main-f197fd28161dc18e.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/pages/_app-33f6d09453147a56.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/fec483df-bc27d8724c538321.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/3512-0415a6edbe900cf0.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/5714-262b8f1a5c5bffef.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/4737-913ae8136f7e81b8.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/2934-04a5cb63259a0ffd.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/3668-90fbd8102251353e.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/chunks/pages/Reviews/%5Bid%5D-2350afd83d993afe.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/119894e5/_buildManifest.js">
#   </script>
#   <script defer="" src="/ei-reviews-next/assets/_next/static/119894e5/_ssgManifest.js">
#   </script>
#   <script src="https://unpkg.com/web-vitals@5.0.0/dist/web-vitals.iife.js">
#   </script>
#   <script async="" src="https://cdn.cookielaw.org/scripttemplates/202407.2.0/otBannerSdk.js" type="text/javascript">
#   </script>
#   <style id="onetrust-style">
#    #onetrust-banner-sdk .onetrust-vendors-list-handler{cursor:pointer;color:#1f96db;font-size:inherit;font-weight:bold;text-decoration:none;margin-left:5px}#onetrust-banner-sdk .onetrust-vendors-list-handler:hover{color:#1f96db}#onetrust-banner-sdk:focus{outline:2px solid #000;outline-offset:-2px}#onetrust-banner-sdk a:focus{outline:2px solid #000}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{outline-offset:1px}#onetrust-banner-sdk.ot-bnr-w-logo .ot-bnr-logo{height:64px;width:64px}#onetrust-banner-sdk .ot-tcf2-vendor-count.ot-text-bold{font-weight:bold}#onetrust-banner-sdk .ot-close-icon,#onetrust-pc-sdk .ot-close-icon,#ot-sync-ntfy .ot-close-icon{background-size:contain;background-repeat:no-repeat;background-position:center;height:12px;width:12px}#onetrust-banner-sdk .powered-by-logo,#onetrust-banner-sdk .ot-pc-footer-logo a,#onetrust-pc-sdk .powered-by-logo,#onetrust-pc-sdk .ot-pc-footer-logo a,#ot-sync-ntfy .powered-by-logo,#ot-sync-ntfy .ot-pc-footer-logo a{background-size:contain;background-repeat:no-repeat;background-position:center;height:25px;width:152px;display:block;text-decoration:none;font-size:.75em}#onetrust-banner-sdk .powered-by-logo:hover,#onetrust-banner-sdk .ot-pc-footer-logo a:hover,#onetrust-pc-sdk .powered-by-logo:hover,#onetrust-pc-sdk .ot-pc-footer-logo a:hover,#ot-sync-ntfy .powered-by-logo:hover,#ot-sync-ntfy .ot-pc-footer-logo a:hover{color:#565656}#onetrust-banner-sdk h3 *,#onetrust-banner-sdk h4 *,#onetrust-banner-sdk h6 *,#onetrust-banner-sdk button *,#onetrust-banner-sdk a[data-parent-id] *,#onetrust-pc-sdk h3 *,#onetrust-pc-sdk h4 *,#onetrust-pc-sdk h6 *,#onetrust-pc-sdk button *,#onetrust-pc-sdk a[data-parent-id] *,#ot-sync-ntfy h3 *,#ot-sync-ntfy h4 *,#ot-sync-ntfy h6 *,#ot-sync-ntfy button *,#ot-sync-ntfy a[data-parent-id] *{font-size:inherit;font-weight:inherit;color:inherit}#onetrust-banner-sdk .ot-hide,#onetrust-pc-sdk .ot-hide,#ot-sync-ntfy .ot-hide{display:none !important}#onetrust-banner-sdk button.ot-link-btn:hover,#onetrust-pc-sdk button.ot-link-btn:hover,#ot-sync-ntfy button.ot-link-btn:hover{text-decoration:underline;opacity:1}#onetrust-pc-sdk .ot-sdk-row .ot-sdk-column{padding:0}#onetrust-pc-sdk .ot-sdk-container{padding-right:0}#onetrust-pc-sdk .ot-sdk-row{flex-direction:initial;width:100%}#onetrust-pc-sdk [type=checkbox]:checked,#onetrust-pc-sdk [type=checkbox]:not(:checked){pointer-events:initial}#onetrust-pc-sdk [type=checkbox]:disabled+label::before,#onetrust-pc-sdk [type=checkbox]:disabled+label:after,#onetrust-pc-sdk [type=checkbox]:disabled+label{pointer-events:none;opacity:.7}#onetrust-pc-sdk #vendor-list-content{transform:translate3d(0, 0, 0)}#onetrust-pc-sdk li input[type=checkbox]{z-index:1}#onetrust-pc-sdk li .ot-checkbox label{z-index:2}#onetrust-pc-sdk li .ot-checkbox input[type=checkbox]{height:auto;width:auto}#onetrust-pc-sdk li .host-title a,#onetrust-pc-sdk li .ot-host-name a,#onetrust-pc-sdk li .accordion-text,#onetrust-pc-sdk li .ot-acc-txt{z-index:2;position:relative}#onetrust-pc-sdk input{margin:3px .1ex}#onetrust-pc-sdk .pc-logo,#onetrust-pc-sdk .ot-pc-logo{height:60px;width:180px;background-position:center;background-size:contain;background-repeat:no-repeat;display:inline-flex;justify-content:center;align-items:center}#onetrust-pc-sdk .pc-logo img,#onetrust-pc-sdk .ot-pc-logo img{max-height:100%;max-width:100%}#onetrust-pc-sdk .screen-reader-only,#onetrust-pc-sdk .ot-scrn-rdr,.ot-sdk-cookie-policy .screen-reader-only,.ot-sdk-cookie-policy .ot-scrn-rdr{border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}#onetrust-pc-sdk.ot-fade-in,.onetrust-pc-dark-filter.ot-fade-in,#onetrust-banner-sdk.ot-fade-in{animation-name:onetrust-fade-in;animation-duration:400ms;animation-timing-function:ease-in-out}#onetrust-pc-sdk.ot-hide{display:none !important}.onetrust-pc-dark-filter.ot-hide{display:none !important}#ot-sdk-btn.o ...
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h5,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description {
#                         color: #727272;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th {
#                         color: #727272;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group {
#                         color: #727272;
#                     }
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title {
#                             color: #727272;
#                         }
#
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th {
#                             background-color: #F8F8F8;
#                         }
#
#             .ot-floating-button__front{background-image:url('https://cdn.cookielaw.org/logos/static/ot_persistent_cookie_icon.png')}
#   </style>
#   <style id="googleidentityservice_button_styles">
#    .qJTHM{-webkit-user-select:none;color:#202124;direction:ltr;-webkit-touch-callout:none;font-family:"Roboto-Regular",arial,sans-serif;-webkit-font-smoothing:antialiased;font-weight:400;margin:0;overflow:hidden;-webkit-text-size-adjust:100%}.ynRLnc{left:-9999px;position:absolute;top:-9999px}.L6cTce{display:none}.bltWBb{word-break:break-all}.hSRGPd{color:#1a73e8;cursor:pointer;font-weight:500;text-decoration:none}.Bz112c-W3lGp{height:16px;width:16px}.Bz112c-E3DyYd{height:20px;width:20px}.Bz112c-r9oPif{height:24px;width:24px}.Bz112c-u2z5K{height:36px;width:36px}.Bz112c-uaxL4e{-webkit-border-radius:10px;border-radius:10px}.LgbsSe-Bz112c{display:block}.S9gUrf-YoZ4jf,.S9gUrf-YoZ4jf *{border:none;margin:0;padding:0}.fFW7wc-ibnC6b>.aZ2wEe>div{border-color:#4285f4}.P1ekSe-ZMv3u>div:nth-child(1){background-color:#1a73e8!important}.P1ekSe-ZMv3u>div:nth-child(2),.P1ekSe-ZMv3u>div:nth-child(3){background-image:linear-gradient(to right,rgba(255,255,255,.7),rgba(255,255,255,.7)),linear-gradient(to right,#1a73e8,#1a73e8)!important}.haAclf{display:inline-block}.nsm7Bb-HzV7m-LgbsSe{-webkit-border-radius:4px;border-radius:4px;-webkit-box-sizing:border-box;box-sizing:border-box;-webkit-transition:background-color .218s,border-color .218s;transition:background-color .218s,border-color .218s;-webkit-user-select:none;-webkit-appearance:none;background-color:#fff;background-image:none;border:1px solid #dadce0;color:#3c4043;cursor:pointer;font-family:"Google Sans",arial,sans-serif;font-size:14px;height:40px;letter-spacing:0.25px;outline:none;overflow:hidden;padding:0 12px;position:relative;text-align:center;vertical-align:middle;white-space:nowrap;width:auto}@media screen and (-ms-high-contrast:active){.nsm7Bb-HzV7m-LgbsSe{border:2px solid windowText;color:windowText}}@media screen and (preferes-contrast:more){.nsm7Bb-HzV7m-LgbsSe{color:#000}}.nsm7Bb-HzV7m-LgbsSe.pSzOP-SxQuSe{font-size:14px;height:32px;letter-spacing:0.25px;padding:0 10px}.nsm7Bb-HzV7m-LgbsSe.purZT-SxQuSe{font-size:11px;height:20px;letter-spacing:0.3px;padding:0 8px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe{padding:0;width:40px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.pSzOP-SxQuSe{width:32px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.purZT-SxQuSe{width:20px}.nsm7Bb-HzV7m-LgbsSe.JGcpL-RbRzK{-webkit-border-radius:20px;border-radius:20px}.nsm7Bb-HzV7m-LgbsSe.JGcpL-RbRzK.pSzOP-SxQuSe{-webkit-border-radius:16px;border-radius:16px}.nsm7Bb-HzV7m-LgbsSe.JGcpL-RbRzK.purZT-SxQuSe{-webkit-border-radius:10px;border-radius:10px}.nsm7Bb-HzV7m-LgbsSe.MFS4be-Ia7Qfc{border:none;color:#fff}.nsm7Bb-HzV7m-LgbsSe.MFS4be-v3pZbf-Ia7Qfc{background-color:#1a73e8}.nsm7Bb-HzV7m-LgbsSe.MFS4be-JaPV2b-Ia7Qfc{background-color:#202124;color:#e8eaed}@media screen and (prefers-contrast:more){.nsm7Bb-HzV7m-LgbsSe.MFS4be-JaPV2b-Ia7Qfc{color:#fff}}.nsm7Bb-HzV7m-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{height:18px;margin-right:8px;min-width:18px;width:18px}.nsm7Bb-HzV7m-LgbsSe.pSzOP-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{height:14px;min-width:14px;width:14px}.nsm7Bb-HzV7m-LgbsSe.purZT-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{height:10px;min-width:10px;width:10px}.nsm7Bb-HzV7m-LgbsSe.jVeSEe .nsm7Bb-HzV7m-LgbsSe-Bz112c{margin-left:8px;margin-right:-4px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{margin:0;padding:10px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.pSzOP-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{padding:8px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.purZT-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{padding:4px}.nsm7Bb-HzV7m-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf{-webkit-border-top-left-radius:3px;border-top-left-radius:3px;-webkit-border-bottom-left-radius:3px;border-bottom-left-radius:3px;display:-webkit-box;display:-webkit-flex;display:flex;justify-content:center;-webkit-align-items:center;align-items:center;background-color:#fff;height:36px;margin-left:-10px;margin-right:12px;min-width:36px;width:36px}.nsm7Bb-HzV7m-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf .nsm7Bb-HzV7m-LgbsSe-Bz112c,.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf . ...
#   </style>
#   <link href="https://accounts.google.com/gsi/style" id="googleidentityservice" media="all" rel="stylesheet" type="text/css"/>
#   <meta content="A8o5T4MyEkRZqLA9WeG2XTFdV5tsX2Prg85xyQ+RL1btVuybB1K/EQ+7JUsPK+J32oBMTnsoF9B4A+qTlL6efgQAAABweyJvcmlnaW4iOiJodHRwczovL2FjY291bnRzLmdvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IkZlZENtQnV0dG9uTW9kZSIsImV4cGlyeSI6MTc0NDY3NTIwMCwiaXNUaGlyZFBhcnR5Ijp0cnVlfQ==" http-equiv="origin-trial"/>
#   <style id="qual_style-ide" type="text/css">
#   </style>
#   <style id="qual_style-igs" type="text/css">
#   </style>
#  </head>
#  <body class="main gdGrid lang-en en-US" data-locale="en-US" marginheight="0" marginwidth="0">
#   <div id="__next">
#    <div class="SkipToLinks_container__DqK_n" id="SkipToLinks" style="display: flex; gap: 1em; position: absolute; z-index: 999; left: -9999px; opacity: 0; margin: 1em;">
#     <a href="#__next">
#      Skip to content
#     </a>
#     <a href="#GlobalFooter">
#      Skip to footer
#     </a>
#    </div>
#    <div id="MarketingBanner">
#    </div>
#    <script nonce="">
#     window.__GD_MARKETINGBANNER_CONTEXT__ = {"deviceInfo":{"tldId":1,"domain":"www.glassdoor.com","platform":"o","view":"w","device":"dk"},"locale":"en-US","oz":{"marketingBanner":{"en-US":{"name":"marketingBanner.en-US","enabled":true,"paramName2Value":{"BPTW2025BannerEnabledPageAllowList":[]},"message":""}}},"pageName":"ei-reviews"};
#    </script>
#    <div id="UserAlert">
#    </div>
#    <script nonce="">
#     window.__GD_USER_ALERT_DATA__ = {"isEligibleForRestoreAccessAlert":false,"isEligibleForVerifyEmailAlert":false};
# window.__GD_USER_ALERT_CONTEXT__ = {"locale":"en-US"};
#    </script>
#    <div id="globalNav">
#     <div>
#      <div class="eETMxFAmLQFw57WO998k" data-nav-container="true" data-test="global-nav-container" id="signedOutGlobalNav" style="transition: none; position: fixed; top: -65px;">
#       <div class="VaSm25ekNqd7j80xsdOp">
#        <div class="M3DJ_Xj_YUnTn4s2bCeH n7bYJcXwNLKj_M6oYkNx">
#         <a aria-label="Glassdoor Home" data-test="global-nav-glassdoor-logo" href="/index.htm" rel="nofollow" target="_top">
#          <span class="iyknrLJC5gxdw07oZYHL" data-test="logo-svg">
#           <svg fill="none" height="36" viewbox="0 0 120 36" width="120" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M115.399 14.355h4.539c.034 0 .062-.03.062-.067V9.812c-.001-1.094-.363-1.984-1.096-2.606-.674-.572-1.686-.917-3.039-.985-.034-.002-.062.027-.062.063v1.688c0 .033.025.06.056.063 1.187.083 2.09.466 2.09 1.8l-2.55.001c-.034 0-.062.03-.062.067v4.386c0 .036.028.066.062.066m-98.18 3.623h-5.504c-.086 0-.141.077-.141.153v2.956c0 .093.07.153.141.153h1.955v2.38c0 1.77-.432 2.72-1.955 2.72-1.272 0-2.175-.771-2.175-3.169V16.26c0-2.296.684-3.372 2.199-3.372 1.366 0 1.923.839 1.923 2.406v.89c0 .093.071.152.142.152h3.384c.086 0 .141-.076.141-.152V15.14c.031-3.718-1.947-5.684-5.527-5.684s-5.912 2.127-5.912 6.6v7.395c0 4.405 2.716 6.32 5.731 6.32 3.376 0 5.731-1.33 5.731-6.252v-5.397a.147.147 0 0 0-.133-.152h-.008.008zm10.536 7.876h-5.292V9.979c0-.094-.07-.153-.141-.153h-3.33c-.086 0-.14.076-.14.153v19.289c0 .093.07.152.14.152h8.755c.086 0 .141-.076.141-.152v-3.253c0-.093-.07-.153-.141-.153h.008zm49.73-9.748c0-4.447 2.284-6.616 5.778-6.616 3.447 0 5.763 2.177 5.747 6.616v7.048c0 4.507-2.143 6.582-5.747 6.582s-5.778-2.033-5.778-6.582zm5.778 10.25c1.46 0 2.065-1.067 2.065-3.337v-6.752c0-2.27-.589-3.371-2.065-3.371s-2.065 1.143-2.065 3.371v6.752c0 2.279.605 3.337 2.065 3.337M96.195 9.49c-3.494 0-5.779 2.169-5.779 6.616v7.048c0 4.55 2.175 6.582 5.779 6.582s5.747-2.075 5.747-6.582v-7.048c.016-4.439-2.3-6.616-5.747-6.616M98.26 23.02c0 2.27-.605 3.337-2.065 3.337s-2.065-1.059-2.065-3.337v-6.752c0-2.228.589-3.371 2.065-3.371s2.065 1.1 2.065 3.371zM65.285 9.82h4.993v.017c3.376 0 5.92 1.855 5.92 6.43v6.718c0 4.532-2.481 6.43-5.96 6.43h-4.953c-.071 0-.142-.06-.142-.153V9.99c0-.085.055-.17.142-.17m4.797 16.028c1.507 0 2.45-1.034 2.45-3.448l.007.008v-5.887c0-2.44-.989-3.423-2.489-3.423h-1.374v12.75zM47.078 9.456h-.055c-3.439 0-5.252 2.118-5.252 5.295 0 3.307 2.136 4.846 3.898 6.115l.341.247.409.297.001.001.001.001c1.244.9 2.204 1.594 2.204 3.123 0 1.28-.785 1.788-1.696 1.813-1.005.025-1.735-.805-1.735-1.847v-1.686a.19.19 0 0 0-.189-.194h-3.219c-.11 0-.188.084-.188.195v1.71c0 3.38 1.9 5.253 5.245 5.253 3.344 0 5.37-1.915 5.37-5.278 0-3.502-2.074-5.015-3.881-6.335l-.06-.044a43 43 0 0 0-.596-.428c-1.238-.88-2.388-1.697-2.388-2.969 0-1.262.8-1.855 1.727-1.855.998 0 1.704.771 1.704 1.788v1.49c0 .11.087.195.189.195h3.219c.11 0 .188-.084.188-.194V14.7c.008-3.32-1.994-5.227-5.237-5.244m11.563 0h.055c3.243.017 5.237 1.923 5.237 5.244v1.449c0 .11-.078.194-.188.194h-3.22a.19.19 0 0 1-.188-.194v-1.491c0-1.017-.706-1.788-1.704-1.788-.926 0-1.727.593-1.727 1.855 0 1.271 1.15 2.089 2.388 2.969q.298.21.596.428l.06.044c1.808 1.32 3.881 2.833 3.881 6.335 0 3.363-2.026 5.278-5.37 5.278s-5.245-1.872-5.245-5.252v-1.712c0-.11.079-.194.188-.194h3.22c.102 0 .188.084.188.195V24.5c0 1.042.73 1.872 1.735 1.847.91-.025 1.696-.534 1.696-1.813 0-1.53-.96-2.223-2.203-3.123q-.202-.145-.411-.3l-.338-.244-.003-.002c-1.763-1.269-3.9-2.808-3.9-6.115 0-3.177 1.815-5.295 5.253-5.295m55.47 6.398v-1.618c0-2.465-1.9-4.405-4.083-4.405h-6.485c-.078 0-.141.068-.141.152v19.273c0 .084.063.152.141.152h3.172c.086 0 .141-.076.141-.152v-8.023h1.555c1.445 0 1.9.576 1.9 2.042v5.964c0 .093.071.152.141.152h3.274a.153.153 0 0 0 .149-.152v-5.854c0-2-.51-3.279-1.813-3.804 1.311-.576 2.049-1.728 2.049-3.727m-3.549.678c0 .804-.597 1.448-1.335 1.448h-2.41v-4.896h2.41c.738 0 1.335.644 1.335 1.44v2.008m-77.1-6.701h3.377c.063 0 .125.05.141.127l4.381 19.247c.04.11-.04.212-.141.212h-3.235c-.055 0-.126-.051-.141-.128l-.691-3.447h-4.036l-.69 3.447a.15.15 0 0 1-.142.127H29.05c-.094 0-.165-.101-.141-.211L33.32 9.958a.14.14 0 0 1 .142-.127m1.642 6.116-1.335 6.659h2.7l-1.334-6.659-.016.093zM4.6 9.827H.062c-.034 0-.062.03-.062.066v4.385c0 .037.028.067.062.067h2.55c0 1.335-.903 1.718-2.09 1.801a.06.06 0 0 0-.056.063v1.689c0 .035.029.064.062.062 1.353-.068 2.365-.413 3.039-.985.733-.622 1.095-1.512 1.096-2.606V9.893c0-.037-.028-.067-.062-.067" fill="#00A264" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </a>
#        </div>
#        <ul class="GfZWzXjqUMq_Izv5zVR_" data-test="content-menu" id="ContentNav">
#         <li class="ji8JI0ibjBNKYy6dBuvi" data-test="site-header-community">
#          <div class="MCXNsDKjY6X3C5eZ7bV8">
#           <div class="d-flex justify-content-center align-items-center">
#            <dotlottie-player mode="normal" src="/assets/lottie/global-nav/CommunityReactions.lottie" style="flex-basis: content;">
#            </dotlottie-player>
#           </div>
#          </div>
#          <a href="/Community/index.htm" tabindex="0">
#           Community
#          </a>
#         </li>
#         <li class="ji8JI0ibjBNKYy6dBuvi" data-test="site-header-jobs">
#          <a href="/Job/index.htm" tabindex="0">
#           Jobs
#          </a>
#         </li>
#         <li class="ji8JI0ibjBNKYy6dBuvi" data-test="site-header-companies">
#          <a href="/Reviews/index.htm" tabindex="0">
#           Companies
#          </a>
#         </li>
#         <li class="ji8JI0ibjBNKYy6dBuvi" data-test="site-header-salaries">
#          <a href="/Salaries/index.htm" tabindex="0">
#           Salaries
#          </a>
#         </li>
#         <li class="ji8JI0ibjBNKYy6dBuvi" data-test="site-header-for-employers">
#          <a href="/employers/?source=gdemployermenu" tabindex="0">
#           For Employers
#          </a>
#         </li>
#        </ul>
#        <div class="GVIQd5DhATEL1vVk7Im2" id="HamburgerButton">
#         <button aria-label="Navigation Menu" class="vSjM__RcTMF6FIzfqoJi" title="Open Navigation Menu" type="button">
#          <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <g fill="currentColor" fill-rule="evenodd">
#            <path d="M21 11H3a1 1 0 0 0 0 2h18a1 1 0 0 0 0-2M3 5h18a1 1 0 0 0 0-2H3a1 1 0 0 0 0 2M21 19H3a1 1 0 0 0 0 2h18a1 1 0 0 0 0-2">
#            </path>
#           </g>
#          </svg>
#         </button>
#        </div>
#        <div class="YW7oTiagO98827_YPatc xE8tJBEJXRfz1WQWq80l OhNWQeOFjx4sPrk_Gafu" data-test="global-nav-utility-nav" id="UtilityNav">
#         <div class="irr1Ai9s4VDkmy2qzEe4">
#          <button class="_KVCMzQsjWmGZ0RHhuNW DlP_4HJeFpiO5Pf_cykP" data-test="search-button" type="button">
#           <div class="vnGVmdC3e4CjjHtwEMhk" data-test="search-logo">
#            <div class="d-flex justify-content-center align-items-center">
#             <dotlottie-player mode="normal" src="/assets/lottie/global-nav/MagnifyingGlass.lottie" style="flex-basis: content;">
#             </dotlottie-player>
#            </div>
#           </div>
#           <span class="FC6oAfJh3wmMzcxoDXe7" data-test="search-label">
#            Search
#           </span>
#          </button>
#          <div class="rQ7JPJmfsqRlC9ESH37x">
#           <div class="prI8gBTsYtdTKNf4NSWa" data-test="search-bar">
#            <div class="OGTqDyUWptcn8kpKEcsz" data-test="expanded-search-container">
#             <div class="YVJUUvjR6ujtBjUbqYHi" data-test="keyword-search-input-container">
#              <div class="GmwJzdwvhvDCQxnQfD5e">
#               <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M6.4 11.601a5.2 5.2 0 1 0 0-10.4 5.2 5.2 0 0 0 0 10.4m0 1.2a6.4 6.4 0 1 0 0-12.8 6.4 6.4 0 0 0 0 12.8M12.175 11.326l3.824 3.825-.848.849-3.825-3.825z" fill="#727272" fill-rule="evenodd">
#                </path>
#               </svg>
#              </div>
#              <div class="QxH5QtI1le7Sel54IJpq">
#               <input aria-label="Search" autocomplete="off" class="Fm6MWqTBHACmTV3VXcOQ" data-test="keyword-search-input" id="sc.keyword" placeholder="Search" type="text" value=""/>
#               <ul class="OYYKmsCwFWIzXCS4TmU3 OODoNKcvije0UCjtZPWR DbYBgj_2s_QhTO7gQGa4" data-test="keyword-search-autocomplete-suggestions-container" id="SearchKeywordResults">
#               </ul>
#               <div class="fAV3TKwJPJFRbhVgiYVt">
#               </div>
#              </div>
#             </div>
#             <div class="VjnTEGjn18SYbBFhqeqZ" data-test="location-search-input-container">
#              <div class="GmwJzdwvhvDCQxnQfD5e">
#               <svg fill="none" height="18" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M12.738 7.4c0-3.093-2.452-5.6-5.478-5.6S1.783 4.307 1.783 7.4c0 2.788 1.798 5.657 5.477 8.593 3.68-2.936 5.478-5.805 5.478-8.593M7.26 17Q1 12.2 1 7.4C1 3.865 3.803 1 7.26 1s6.26 2.865 6.26 6.4q0 4.8-6.26 9.6m0-8c.865 0 1.565-.716 1.565-1.6s-.7-1.6-1.565-1.6c-.864 0-1.565.716-1.565 1.6S6.396 9 7.26 9m0 .8c-1.296 0-2.347-1.075-2.347-2.4S5.962 5 7.26 5s2.348 1.075 2.348 2.4S8.556 9.8 7.26 9.8" fill="#727272" fill-rule="evenodd">
#                </path>
#                <path d="m7.26 15.993-.156.195.156.125.156-.125zm0 1.007-.152.198.152.117.152-.117zm5.728-9.6c0-3.226-2.56-5.85-5.728-5.85v.5c2.882 0 5.228 2.39 5.228 5.35zM7.26 1.55c-3.168 0-5.727 2.624-5.727 5.85h.5c0-2.96 2.345-5.35 5.227-5.35zM1.533 7.4c0 2.902 1.87 5.835 5.571 8.788l.312-.39C3.76 12.877 2.033 10.073 2.033 7.4zm5.883 8.788c3.7-2.953 5.572-5.886 5.572-8.788h-.5c0 2.674-1.726 5.479-5.384 8.397zm-.004.614C3.262 13.619 1.25 10.483 1.25 7.4h-.5c0 3.317 2.162 6.581 6.358 9.798zM1.25 7.4c0-3.402 2.696-6.15 6.01-6.15v-.5C3.66.75.75 3.733.75 7.4zm6.01-6.15c3.314 0 6.01 2.748 6.01 6.15h.5c0-3.667-2.91-6.65-6.51-6.65zm6.01 6.15c0 3.083-2.011 6.219-6.162 9.402l.304.396c4.196-3.217 6.358-6.481 6.358-9.798zM7.26 9.25c1.008 0 1.815-.834 1.815-1.85h-.5c0 .75-.594 1.35-1.315 1.35zM9.075 7.4c0-1.016-.807-1.85-1.815-1.85v.5c.721 0 1.315.6 1.315 1.35zM7.26 5.55c-1.007 0-1.815.834-1.815 1.85h.5c0-.75.594-1.35 1.315-1.35zM5.445 7.4c0 1.016.808 1.85 1.815 1.85v-.5c-.72 0-1.315-.6-1.315-1.35zM7.26 9.55c-1.153 0-2.097-.957-2.097-2.15h-.5c0 1.458 1.157 2.65 2.597 2.65zM5.163 7.4c0-1.193.944-2.15 2.097-2.15v-.5c-1.44 0-2.597 1.192-2.597 2.65zM7.26 5.25c1.153 0 2.098.957 2.098 2.15h.5c0-1.458-1.158-2.65-2.598-2.65zM9.358 7.4c0 1.193-.945 2.15-2.098 2.15v.5c1.44 0 2.598-1.192 2.598-2.65z" fill="#727272">
#                </path>
#               </svg>
#              </div>
#              <div class="QxH5QtI1le7Sel54IJpq">
#               <input aria-label="Location" autocomplete="off" class="Fm6MWqTBHACmTV3VXcOQ" data-test="location-search-input" id="sc.location" placeholder="Location" type="text" value=""/>
#               <ul class="OODoNKcvije0UCjtZPWR DbYBgj_2s_QhTO7gQGa4" data-test="location-search-autocomplete-suggestions-container" id="SearchLocationResults">
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="zfumUGHc6GCJyKQelsjI">
#          </div>
#         </div>
#         <div class="VKqKWgo67Fgil00gT_Bu">
#          <div>
#           <div class="I6oy4snwFNvVqaveooyl" data-test="utility-nav-container">
#            <div class="WmBUThB2pIPJRHRIHp2F" data-test="utility-nav-dropdown" role="presentation">
#             <button aria-label="notifications" class="M9PzFmbStzj0y7I9fmMS" data-test="utility-nav-notification-button" type="button">
#              <div class="d-flex justify-content-center align-items-center">
#               <dotlottie-player mode="normal" src="/assets/lottie/global-nav/WebNotificationBell.lottie" style="flex-basis: content; width: 48px; height: 48px;">
#               </dotlottie-player>
#              </div>
#              <div style="display: initial;">
#               <span class="h4oaeYYSp9_JCZdQJ0Kk" data-test="notification-alert-badge">
#                3
#               </span>
#              </div>
#             </button>
#             <div class="wWUfVXKS9AsmPiJzQDja" data-test="utility-nav-dropdown-menu" role="presentation">
#              <div class="E4NrVYAX9Fte7s17P3Nw" data-test="utility-nav-notification-list">
#               <div class="m1OTrfslLRmEqgJbBYRl">
#                <div class="ZsSzcq8t6F3Oq_i9jZfl" data-test="utility-nav-notification-header">
#                 Notifications
#                </div>
#               </div>
#               <div class="Q8sdS_jcuSylnw9DWVPV">
#                <a class="ozBSuOOlhz3ngo3t6zhw" data-message-id="6886ec9064e5dfa35264a171" data-test="utility-nav-notification-item-link" href="/Community/the-worklife-bowl/want-to-smash-my-head-into-the-wall-applied-to-a-company-that-matches-my-skills-exactly-and-really-wanted-to-work-there-i">
#                 <div class="k8_1PHdTzeQvMgtEoAfB">
#                  Trending Community posts 🔥
#                 </div>
#                 <div class="DoIbikgpFHpo_GzohxjK">
#                  <span class="Iu_jwVYopQsU0Bgy7NDM" data-test="utility-nav-notification-item-icon">
#                   <img alt="bowl icon" loading="lazy" src="https://dslntlv9vhjr4.cloudfront.net/crowd_images/the-worklife-bowl_su7Ai.png"/>
#                  </span>
#                  <span class="iv3G7bRdxRjQpPcPR9en" data-test="utility-nav-notification-item-title">
#                   The Worklife Bowl
#                  </span>
#                 </div>
#                 <span class="rKCPjeUF7dtC5IylIOhH vLc44REDiAjWFXuLw_jk" data-test="utility-nav-notification-item-message">
#                  Financial Analyst: "Want to smash my head into the wall. Applied to a company that matches my skills exactly and really wanted to work there. I applied and when reviewing my resume I made a major typo and forgot a word. I can’t change it now so RIP"
#                 </span>
#                 <div class="hOrNKuVyG1rZZTIabbnR" data-test="utility-nav-notification-item-reactions">
#                  <div class="zb1SZ7p4wv6bIEsR0pBq">
#                   <div>
#                    <span class="Iu_jwVYopQsU0Bgy7NDM">
#                     <svg fill="none" height="16" viewbox="0 0 32 32" width="16" xmlns="http://www.w3.org/2000/svg">
#                      <path d="M16.013 32.007c8.836 0 16-7.163 16-16s-7.163-16-16-16-16 7.164-16 16 7.163 16 16 16" fill="#4DD783">
#                      </path>
#                      <path d="M24.224 9.428c-2.01-2.003-5.312-1.817-7.078.397l-1.095 1.363c-.006.013-.025.013-.038 0L14.886 9.78a4.76 4.76 0 0 0-7.046-.429l-.006.007a4.75 4.75 0 0 0-.55 6.157l8.575 9.894c.09.102.25.102.34 0l8.537-9.862a4.744 4.744 0 0 0-.512-6.119Z" fill="#fff" stroke="#000" stroke-width="1.12">
#                      </path>
#                     </svg>
#                    </span>
#                    <span class="Iu_jwVYopQsU0Bgy7NDM">
#                     <svg fill="none" height="16" viewbox="0 0 32 32" width="16" xmlns="http://www.w3.org/2000/svg">
#                      <path d="M16 32c8.837 0 16-7.163 16-16S24.837 0 16 0 0 7.163 0 16s7.163 16 16 16" fill="#FFBE26">
#                      </path>
#                      <path d="M18.957 17.92a3.066 3.066 0 0 1-6.131 0" stroke="#000" stroke-width="1.12">
#                      </path>
#                      <path d="M29.914 11.776a5.967 5.967 0 0 1-5.965 5.965 5.97 5.97 0 0 1-5.972-5.965 5.968 5.968 0 0 1 11.936 0ZM13.811 11.776a5.967 5.967 0 0 1-5.965 5.965 5.967 5.967 0 0 1-5.964-5.965 5.967 5.967 0 0 1 5.964-5.965 5.97 5.97 0 0 1 5.965 5.965Z" fill="#fff" stroke="#000" stroke-width="1.12">
#                      </path>
#                      <path d="M17.978 12.454a2.08 2.08 0 1 0-4.16 0" stroke="#000" stroke-width="1.12">
#                      </path>
#                      <path d="M10.451 11.962a.909.909 0 1 1-1.817 0 .909.909 0 0 1 1.817 0ZM23.347 12a.909.909 0 1 1-1.817 0 .909.909 0 0 1 1.817 0Z" fill="#000" stroke="#000" stroke-width="0.064">
#                      </path>
#                     </svg>
#                    </span>
#                   </div>
#                   <span>
#                    11
#                   </span>
#                  </div>
#                 </div>
#                </a>
#                <a class="ozBSuOOlhz3ngo3t6zhw" data-message-id="6882e3f12332f7abf5943aa1" data-test="utility-nav-notification-item-link" href="/Community/personal-investment-chatter/how-can-i-do-options-trading-with-my-retirement-accounts-i-have-a-401k-balance-but-not-working-at-the-moment-i-also-have-a-roth-t1s8-5">
#                 <div class="k8_1PHdTzeQvMgtEoAfB">
#                  Trending Community posts 🔥
#                 </div>
#                 <div class="DoIbikgpFHpo_GzohxjK">
#                  <span class="Iu_jwVYopQsU0Bgy7NDM" data-test="utility-nav-notification-item-icon">
#                   <img alt="bowl icon" loading="lazy" src="https://dslntlv9vhjr4.cloudfront.net/crowd_images/WBG8iZgt8gjA0.png"/>
#                  </span>
#                  <span class="iv3G7bRdxRjQpPcPR9en" data-test="utility-nav-notification-item-title">
#                   Personal Investment Chatter
#                  </span>
#                 </div>
#                 <span class="rKCPjeUF7dtC5IylIOhH vLc44REDiAjWFXuLw_jk" data-test="utility-nav-notification-item-message">
#                  Guidehouse: "How can I do options trading with my retirement accounts? I have a 401k balance but I am not working at the moment.
#
# I also have a Roth balance so moving the 401k funds to a tIRA might be tricky."
#                 </span>
#                 <div class="hOrNKuVyG1rZZTIabbnR" data-test="utility-nav-notification-item-reactions">
#                  <div class="zb1SZ7p4wv6bIEsR0pBq">
#                   <div>
#                    <span class="Iu_jwVYopQsU0Bgy7NDM">
#                     <svg fill="none" height="16" viewbox="0 0 32 32" width="16" xmlns="http://www.w3.org/2000/svg">
#                      <path d="M16 32c8.837 0 16-7.163 16-16S24.837 0 16 0 0 7.163 0 16s7.163 16 16 16" fill="#FFE126">
#                      </path>
#                      <path d="M19.04 25.747c-3.533.947-7.174-1.222-8.102-4.678l-.935-3.488c-.173-.64.211-1.3.851-1.472l10.458-2.803c.64-.173 1.3.21 1.472.85l.934 3.489c.928 3.469-1.145 7.155-4.678 8.102Z" fill="#fff" stroke="#000" stroke-width="1.12">
#                      </path>
#                      <path d="M22.714 6.26c-4.487 0-5.812 2.796-5.812 2.796.717-.595 3.744-1.594 6.131.82M15.45 23.974c.3-1.197 1.197-2.189 2.438-2.521 1.242-.333 2.515.076 3.373.966M6.854 10.374c3.885-2.246 6.433-.48 6.433-.48-.916-.153-4.045.493-4.903 3.783" stroke="#000" stroke-width="1.12">
#                      </path>
#                     </svg>
#                    </span>
#                    <span class="Iu_jwVYopQsU0Bgy7NDM">
#                     <svg fill="none" height="16" viewbox="0 0 32 32" width="16" xmlns="http://www.w3.org/2000/svg">
#                      <path d="M16.013 32.007c8.836 0 16-7.163 16-16s-7.163-16-16-16-16 7.164-16 16 7.163 16 16 16" fill="#4DD783">
#                      </path>
#                      <path d="M24.224 9.428c-2.01-2.003-5.312-1.817-7.078.397l-1.095 1.363c-.006.013-.025.013-.038 0L14.886 9.78a4.76 4.76 0 0 0-7.046-.429l-.006.007a4.75 4.75 0 0 0-.55 6.157l8.575 9.894c.09.102.25.102.34 0l8.537-9.862a4.744 4.744 0 0 0-.512-6.119Z" fill="#fff" stroke="#000" stroke-width="1.12">
#                      </path>
#                     </svg>
#                    </span>
#                   </div>
#                   <span>
#                    6
#                   </span>
#                  </div>
#                 </div>
#                </a>
#                <a class="ozBSuOOlhz3ngo3t6zhw" data-message-id="688a8a3d86697e4b6950da3d" data-test="utility-nav-notification-item-link" href="/Community/interview-tips/has-anyone-else-skipped-the-recruiter-screen-and-gone-straight-to-a-hiringmanager-interview-a-recruiter-emailed-me-saying">
#                 <div class="k8_1PHdTzeQvMgtEoAfB">
#                  Trending Community posts 🔥
#                 </div>
#                 <div class="DoIbikgpFHpo_GzohxjK">
#                  <span class="Iu_jwVYopQsU0Bgy7NDM" data-test="utility-nav-notification-item-icon">
#                   <img alt="bowl icon" loading="lazy" src="https://dslntlv9vhjr4.cloudfront.net/crowd_images/interview-tips_gJFI5.png"/>
#                  </span>
#                  <span class="iv3G7bRdxRjQpPcPR9en" data-test="utility-nav-notification-item-title">
#                   Interview Tips
#                  </span>
#                 </div>
#                 <span class="rKCPjeUF7dtC5IylIOhH vLc44REDiAjWFXuLw_jk" data-test="utility-nav-notification-item-message">
#                  Associate: "Has anyone else skipped the recruiter screen and gone straight to a hiring‑manager interview?
#
# A recruiter emailed me saying I’ve advanced to the next step and asked for my availability, but we’ve never spoken. I can prep from the job description, but I typically like to rely on the  recruiter call to clarify expectations and team priorities. Any tips on how to prepare?"
#                 </span>
#                 <div class="hOrNKuVyG1rZZTIabbnR" data-test="utility-nav-notification-item-reactions">
#                  <div class="zb1SZ7p4wv6bIEsR0pBq">
#                   <div>
#                    <span class="Iu_jwVYopQsU0Bgy7NDM">
#                     <svg fill="none" height="16" viewbox="0 0 32 32" width="16" xmlns="http://www.w3.org/2000/svg">
#                      <path d="M16 32c8.837 0 16-7.163 16-16S24.837 0 16 0 0 7.163 0 16s7.163 16 16 16" fill="#74C1ED">
#                      </path>
#                      <path d="m18.144 16 .62 3.603 3.06-.915.058-1.952zM17.043 12.8v-.013l-.64 2.803z" fill="#FAFAFA">
#                      </path>
#                      <path d="M19.488 19.648c.576-.576 1.555-.768 2.611-.512l1.171-2.33c.32-.64 1.101-.89 1.735-.563.454.237.64.794.416 1.255l-2.477 4.71c-.557 1.133-2.323 3.405-5.945 2.618-3.463-.756-3.91-3.802-3.61-5.114l.544-2.867 1.037-4.518c.128-.57.697-.928 1.267-.794.57.128.928.697.8 1.267l-.634 2.79 1.402-6.156c.128-.583.71-.941 1.286-.813.583.134.941.71.807 1.286l-1.402 6.157" fill="#FAFAFA">
#                      </path>
#                      <path d="M19.488 19.648c.576-.576 1.555-.768 2.611-.512l1.171-2.33c.32-.64 1.101-.89 1.735-.563.454.237.64.794.416 1.255l-2.477 4.71c-.557 1.133-2.323 3.405-5.945 2.618-3.463-.756-3.91-3.802-3.61-5.114l.544-2.867 1.037-4.518c.128-.57.697-.928 1.267-.794.57.128.928.697.8 1.267l-.634 2.79 1.402-6.156c.128-.583.71-.941 1.286-.813.583.134.941.71.807 1.286l-1.402 6.157" stroke="#000" stroke-linecap="round" stroke-linejoin="round" stroke-width="0.96">
#                      </path>
#                      <path d="m20.602 16.55 1.702-7.481a1.07 1.07 0 0 0-.806-1.287 1.07 1.07 0 0 0-1.287.807L18.51 16.07M22.22 18.9l1.838-8.071a1.048 1.048 0 0 0-2.042-.467l-1.408 6.182" fill="#FAFAFA">
#                      </path>
# ...
# Math.round(this.getDuration()):this.playerInfo&&this.playerInfo.duration?Math.round(this.playerInfo.duration):null},setVideoLength:function(){this._asData.videoLength=this.getVideoLength()},_getCurrentTime:function(){return this.getCurrentTime?Math.round(this.getCurrentTime()):this.playerInfo&&this.playerInfo.currentTime?Math.round(this.playerInfo.currentTime):null},isVideo:function(){return this&&"VIDEO"===this.nodeName},_vidLoaded:function(){this._asData.videoLoaded||(this.setVideoTitle(),this.setVideoLength(),
# this.setMilestones(),this._asData.videoLoaded=!0)},_vidPlay:function(a){var b=void 0===a?this:a.target;b._asData.adPlaying||b._vidLoaded();if(b._asData.adPlaying)b._asData.adPlaying=!1;else if(void 0===a&&this._asData&&"player loaded"===this._asData.eventType&&(this._asData.adPlaying=!0),"autoplay"!==b._asData.eventType&&"click to play"!==b._asData.eventType||0!==b._asData.currentTime){b.milestoneCheck&&window.clearInterval(b.milestoneCheck);b.milestoneCheck=window.setInterval(b._vidMilestones,1E3,
# a);if(b._asData.justFinished&&(b._asData.justFinished=!1,!b._asData.isPlaylist))return;a=b._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===a.length?(b._asData.firstPlay=!1,b._asData.autoplay?b._sendHit(a[1],!0):b._sendHit(a[0],!1)):b._asData.justSeeked||b._sendHit(a,!1);5<Math.abs(b._asData.currentTime-b._asData.previousTime)&&!b._asData.justFinished&&b._sendHit("seek",!1);b._asData.justSeeked=!1}},_vidPause:function(a){var b=a.target;"cued"!==b._asData.eventType&&(window.clearInterval(b.milestoneCheck),
# 5<Math.abs(b._asData.currentTime-b._asData.previousTime)?b._vidSeek(a):b._getCurrentTime()!==b._asData.videoLength&&b._sendHit("pause",!1))},_vidSeek:function(a){a=a.target;"cued"!==a._asData.eventType&&(a._asData.adPlaying||a._asData.justFinished||0===a._asData.currentTime&&(0===a._asData.milestones.length||3===a._asData.milestones.length)||a._asData.justSeeked||a._asData.firstPlay||a._asData.justFinished||a._sendHit("seek",!1),a._asData.justSeeked=!0)},_vidComplete:function(a){a=a.target;if(0<a._asData.milestones.length)for(var b=
# 0;b<a._asData.milestones.length;b++){var c=a._asData.milestones[b];c=c/a._asData.videoLength*100;!Number.isNaN(c)&&0===c%25&&0<c&&100>=c&&(a._asData.hitValue=c,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+c+"%")),!0))}a._asData.justFinished||(a._asData.adPlaying=!1,window.clearInterval(a.milestoneCheck),a._asData.hitValue=100,a._sendHit("complete",!0),a._asData.firstPlay=!0,a._asData.justFinished=!0,a._asData.milestones=[25,50,75],a._asData.isPlaylist?a._asData.finalPlaylistVid||
# (b=a.getPlaylistIndex(),c=a.getPlaylist().length,b+1===c&&(a._asData.finalPlaylistVid=!0),a._asData.autoplay=!0,a._asData.videoLoaded=!1,a._vidLoaded()):(a._asData.autoplay=!1,a.setVideoLength(),a.setMilestones()))},_vidMilestones:function(a){if(void 0!==a){a=a.target;var b=a._getCurrentTime();a._asData.previousTime=b;if(!(b<a._asData.milestones[0])){0===a._asData.milestones.length&&window.clearInterval(a.milestoneCheck);do{var c=a._asData.milestones.splice(0,1)[0];a._asData.firstPlay&&(a._sendHit("autoplay",
# !0),a._asData.firstPlay=!1)}while(c>b);b=c/a._asData.videoLength*100;!Number.isNaN(b)&&0===b%25&&0<b&&100>=b&&(a._asData.hitValue=b,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}}},_vidMuted:function(){if(this.isMuted)if(this.isMuted())this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=!1;else return;else if(this.playerInfo)if(this.playerInfo.muted)this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=
# !1;else return;this._asData.currentTime=this._getCurrentTime();void 0===this._asData.currentTime||1>this._asData.currentTime||(this._asData.justMuted?this._sendHit("mute",!1):this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.previousEventType=this._asData.eventType;this._asData.eventType=a;this._asData.hitValue=
# a.match(/milestone|complete/i)?this._asData.hitValue:null;this._asData.nonInteraction=b;y(this._asData)},setListeners:function(){this.addEventListener("onStateChange",function(a){if(-1===a.data){if("cued"===a.target._asData.eventType)return;if("player loaded"===a.target._asData.eventType){a.target._vidPlay(a);return}if(a.target._asData.videoTitle!==a.target.getVideoTitle()){a.target._asData.milestones=[25,50,75];a.target._asData.autoplay=!1;a.target._asData.firstPlay=!0;a.target._asData.videoLoaded=
# !1;a.target._asData.adPlaying=!1;a.target._vidLoaded();return}}if(5===a.data)a.target._asData.milestones=[25,50,75],a.target._asData.autoplay=!1,a.target._asData.firstPlay=!0,a.target._asData.videoLoaded=!1,a.target._asData.adPlaying=!1,a.target._asData.eventType="cued",a.target._asData.videoTitle="not set";else{a.target._asData.currentTime=a.target._getCurrentTime();var b=[a.target._vidComplete,a.target._vidPlay,a.target._vidPause,a.target._vidSeek];(b=b[a.data]||void 0)&&b(a);a.target._asData.previousTime=
# a.target._asData.currentTime}},!0);this.addEventListener("onVolumeChange",function(a){a=a.target;a._vidMuted()},!0)}},g=[];window._asVideos=g;var f,n=0,e,p=setInterval(function(){l();if(0<e.length){clearInterval(p);var a=window.YT;if(0<e.length){a="undefined"!==typeof a&&"undefined"!==typeof a.Player;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="//www.youtube.com/iframe_api";b.parentNode.insertBefore(a,b)}f=window.setInterval(r,
# 1E3)}}},500);setTimeout(function(){clearInterval(p)},1E4);setTimeout(function(){x()},5E3)}})();
#   </script>
#   <script charset="" id="" type="text/javascript">
#    (function(){var l=setInterval(function(){window.gdGlobals?(clearInterval(l),r()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(l)},1E4);var r=function(){function m(){g=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/player.vimeo.com/.test(a.src)})}function t(){var a=window.Vimeo;"undefined"!==typeof a?(window.clearInterval(h),g.map(n)):5>p?p++:window.clearInterval(h)}function n(a){var b=window.Vimeo;b=new b.Player(a);b._asData=
# {eventType:void 0,videoTitle:"not set",videoPlayer:"Vimeo_iframe",videoLength:"not set",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,vidLoaded:!1,nonInteraction:null,hitValue:0};var c=b,d=u,f;for(f in d)c[f]=d[f];b.setListeners();v.push(b);b._vidLoaded();a._asProcessed=!0}function w(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),
# Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());d>b+c&&(b=d,m(),g.map(function(f){f._asProcessed||n(f)}))},3E3)}var x=function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"vimeo",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,
# videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),u={setMilestones:function(){var a=this,b=window.setInterval(function(){var c=a._asData.videoLength;"not set"!==c&&(a._asData.milestones=a._asData.milestones.map(function(d){return d/100*c}),window.clearInterval(b))},200,a)},setVideoTitle:function(){var a=this;this.getVideoTitle().then(function(b){a._asData.videoTitle=b})},replayOrNewVid:function(){var a=this;this._asData.milestones=
# [25,50,75];this.getVideoTitle().then(function(b){a._asData.videoTitle===b?(a._asData.justFinished=!1,a.setMilestones()):a._vidLoaded();a._vidPlay()})},setVideoLength:function(){var a=this;this.getDuration().then(function(b){a._asData.videoLength=Math.round(b)})},_asGetCurrentTime:function(){var a=this;this.getCurrentTime().then(function(b){a._asData.currentTime=b})},_vidLoaded:function(){var a=this;this.setVideoTitle();this.setVideoLength();this.setMilestones();this.getVolume().then(function(c){0===
# c&&(a._asData.justMuted=!0)});var b=setInterval(function(){"not set"!==a._asData.videoTitle&&clearInterval(b)},75);this._asData.justFinished=!1;this._asData.vidLoaded=!0},_vidPlay:function(){if(!e){var a=this;window.setTimeout(function(){if(!e)if(a._asData.justFinished&&a._asData.firstPlay)a.replayOrNewVid();else{var b=a._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===b.length?(a._asData.firstPlay=!1,a._asData.autoplay?a._sendHit(b[1],!0):a._sendHit(b[0],!1)):a._sendHit(b,!1)}},
# 1E3,a)}},_vidPause:function(){var a=this;a._asData.justFinished||e||window.setTimeout(function(){a._asData.justFinished||e||a.getCurrentTime()!==a._asData.videoLength&&a._sendHit("pause",!1)},1E3,a)},_vidSeek:function(){e||this._asData.justFinished||(e=!0,this._sendHit("seek",!1),window.setTimeout(function(){e=!1},2E3))},_vidComplete:function(){if(0<this._asData.milestones.length)for(var a=0;a<this._asData.milestones.length;a++){var b=this._asData.milestones[a];b=b/this._asData.videoLength*100;!Number.isNaN(b)&&
# 0===b%25&&0<b&&100>=b&&(this._asData.hitValue=b,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}this._asData.hitValue=100;this._sendHit("complete",!0);this._asData.firstPlay=!0;this._asData.justFinished=!0;this._asData.autoplay=!1},_vidMilestones:function(a){this._asData.currentTime=a.seconds;if(!(k||(k=!0,window.setTimeout(function(){k=!1},2E3),this._asData.firstPlay&&3<a.seconds&&this._vidPlay(),a.seconds<this._asData.milestones[0]||0===this._asData.milestones.length))){a=
# a.seconds;do var b=this._asData.milestones.splice(0,1)[0];while(b>a);a=b/this._asData.videoLength*100;!Number.isNaN(a)&&0===a%25&&0<a&&100>=a&&(this._asData.hitValue=a,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+a+"%")),!0))}},_vidMuted:function(a){!1===this._asData.justMuted&&0===a.volume?(this._asData.justMuted=!0,this._sendHit("mute",!1)):this._asData.justMuted&&0<a.volume&&(this._asData.justMuted=!1,this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||
# document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.eventType=a;this._asData.nonInteraction=b;this._asData.hitValue=a.match(/milestone|complete/i)?this._asData.hitValue:null;x(this._asData)},setListeners:function(){this.on("play",function(){this._vidPlay()},!0);this.on("pause",function(){this._vidPause()},!0);this.on("seeked",function(){this._vidSeek()},!0);this.on("ended",function(){this._vidComplete()},
# !0);this.on("timeupdate",function(a){this._vidMilestones(a)},!0);this.on("volumechange",function(a){this._vidMuted(a)},!0);this.on("fullscreenchange",function(){this._vidFullScreen()},!0);this.on("webkitfullscreenchange",function(){this._vidFullScreen()},!0);this.on("mozfullscreenchange",function(){this._vidFullScreen()},!0);this.on("msfullscreenchange",function(){this._vidFullScreen()},!0)}},v=[],h,p=0,g,e=!1,k=!1,q=setInterval(function(){m();if(0<g.length){clearInterval(q);var a=window.Vimeo;if(0<
# g.length){a="undefined"!==typeof a;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="https://player.vimeo.com/api/player.js";b.parentNode.insertBefore(a,b)}h=window.setInterval(t,1E3)}}},500);setTimeout(function(){clearInterval(q)},1E4);setTimeout(function(){w()},5E3)}})();
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/app-install-sam-server/static/lib-60fd606b529b87e2.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/app-install-sam-server/static/marketingBanner-b932678a8eb660e8.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/user-alert-sam-server/static/lib-3e81c5cb5716943a.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/user-alert-sam-server/static/userAlertBanner-015acb2791d438bd.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/sam-global-nav/static/lib-627e6f83fe638a8c.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/sam-global-nav/static/globalNav-90a9f0dc0a5c7c35.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/global-footer-sam/static/lib-d38108e6d0c57d34.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/global-footer-sam/static/legacyFooter-483aeb60c1278a19.min.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/user-login-sam-server/static/legacy/gd-user-login-community-translation-en-US.bundle.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/user-login-sam-server/static/legacy/gd-user-login-community.bundle.js?v=eaead">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/user-login-sam-server/static/legacy/gd-user-login-translation-en-US.bundle.js">
#   </script>
#   <script data-nscript="lazyOnload" defer="true" src="/user-login-sam-server/static/legacy/gd-user-login.bundle.js?v=b4a85">
#   </script>
#   <div id="ExperimentRoot">
#    <div>
#    </div>
#   </div>
#   <div id="AuthPromptModalContainer">
#   </div>
#   <div id="OneTapContainer">
#   </div>
#   <script defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <div id="onetrust-consent-sdk">
#    <div class="onetrust-pc-dark-filter ot-hide ot-fade-in">
#    </div>
#   </div>
#   <script charset="" id="" type="text/javascript">
#    window.GD&&(window.GD.gdpr={},window.GD.gdpr.consentIsGiven=!0);window.GD&&window.GD.triggerGDPRConsentGiven&&window.GD.triggerGDPRConsentGiven();
#   </script>
#   <script charset="" id="" type="text/javascript">
#    if(google_tag_manager["rm"]["885267"](12639).includes("C0017")){var now=new Date,time=now.getTime(),futureTime=time+63072E6;now.setTime(futureTime);document.cookie="_optionalConsent\x3dtrue; path\x3d/; expires\x3d"+now.toUTCString()}else now=new Date,time=now.getTime(),futureTime=time+63072E6,now.setTime(futureTime),document.cookie="_optionalConsent\x3dfalse; path\x3d/; expires\x3d"+now.toUTCString();
#   </script>
#   <script charset="" id="" type="text/javascript">
#    var _kiq=_kiq||[];(function(){setTimeout(function(){var a=document,b=a.getElementsByTagName("script")[0];a=a.createElement("script");a.type="text/javascript";a.async=!0;a.src="//s3.amazonaws.com/ki.js/67252/fQH.js";b.parentNode.insertBefore(a,b)},1)})();
#   </script>
#   <script charset="utf-8" id="" type="text/javascript">
#    (function(){var a=google_tag_manager["rm"]["885267"](12644);a&&_kiq.push(["identify",a])})();
#   </script>
#   <script charset="" id="" type="text/javascript">
#    window.GD&&(window.GD.gdpr={},window.GD.gdpr.consentIsGiven=!0);window.GD&&window.GD.triggerGDPRConsentGiven&&window.GD.triggerGDPRConsentGiven();
#   </script>
#   <script charset="" id="" type="text/javascript">
#    if(google_tag_manager["rm"]["885267"](13000).includes("C0017")){var now=new Date,time=now.getTime(),futureTime=time+63072E6;now.setTime(futureTime);document.cookie="_optionalConsent\x3dtrue; path\x3d/; expires\x3d"+now.toUTCString()}else now=new Date,time=now.getTime(),futureTime=time+63072E6,now.setTime(futureTime),document.cookie="_optionalConsent\x3dfalse; path\x3d/; expires\x3d"+now.toUTCString();
#   </script>
#   <iframe id="qualaroo_dnt_frame" src="//dntcl.qualaroo.com/frame.html" style="width: 1px; height: 1px; display: none; opacity: 0;" title="Qualaroo iframe for nudge">
#   </iframe>
#  </body>
# </html>
